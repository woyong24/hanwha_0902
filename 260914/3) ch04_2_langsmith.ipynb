# %%
# !pip --version

# %%
# !pip install -U langchain langchain_openai

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
# 정상 로드 확인 테스트
print("OpenAI 키:", os.getenv("OPENAI_API_KEY")[:8] + "...")
print("LANGSMITH 키:", os.getenv("LANGSMITH_API_KEY")[:8] + "...")
print("LangSmith 프로젝트:", os.getenv("LANGSMITH_PROJECT"))
# Out:
# OpenAI 키: sk-proj-...
# LANGSMITH 키: lsv2_pt_...
# LangSmith 프로젝트: ex0914

# %%
from langchain_openai import ChatOpenAI
from langchain_teddynote import logging

# %%
llm = ChatOpenAI(model="gpt-5-nano")
response = llm.invoke("러시아의 수도는 어디인가요?")
print(response.content)
# Out:
# 모스크바(Moscow)가 러시아의 수도입니다. 러시아의 정치·경제·문화의 중심 도시이기도 합니다.

# %%
#Langsmith 추적하기
logging.langsmith("ex0914", set_enable=True)
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# ex0914
