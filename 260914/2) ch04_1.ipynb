# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\shproject\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
# !pip install langchain_openai
# Out:
# Requirement already satisfied: langchain_openai in .\.venv\Lib\site-packages (1.6.2)
# Requirement already satisfied: certifi>=2024.6.2 in .\.venv\Lib\site-packages (from langchain_openai) (2026.7.22)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.2 in .\.venv\Lib\site-packages (from langchain_openai) (1.6.3)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in .\.venv\Lib\site-packages (from langchain_openai) (3.13.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in .\.venv\Lib\site-packages (from langchain_openai) (0.14.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (0.12.4)
# Requirement already satisfied: packaging>=23.2.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (26.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (2.13.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain_openai) (0.17.1)
# Requirement already satisfied: anyio in .\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain_openai) (4.15.1)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in .\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain_openai) (3.19)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.2->langchain_openai) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in .\.venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in .\.venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (0.10.4)
# Requirement already satisfied: jiter<1,>=0.16.0 in .\.venv\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain_openai) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain_openai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain_openai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain_openai) (0.4.4)
# Requirement already satisfied: regex in .\.venv\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2026.9.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain_openai) (2.7.0)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# %%
# 일반 답변용
llm = ChatOpenAI(
    temperature=0.1,
    model_name="gpt-5-nano",
)

# logprob 확인용
llm_with_logprob = ChatOpenAI(
    temperature=0.1,
    max_tokens=2048,
    model_name="gpt-4o-mini"
).bind(logprobs=True)

# %%
question = "미국의 수도는 어디인가요"

# %%
# 일반 답변용
# response = llm.invoke(question)

# logprob 확인 답변용
response = llm_with_logprob.invoke(question)

# %%
print(f"[답변]: {response}")
# Out:
# [답변]: content='미국의 수도는 워싱턴 D.C.입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 15, 'total_tokens': 28, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d48d865f86', 'id': 'chatcmpl-ENw269D8nClWmhE4Y6XBTO605XA1a', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': {'content': [{'token': '미', 'bytes': [235, 175, 184], 'logprob': -0.00013095269969198853, 'top_logprobs': []}, {'token': '국', 'bytes': [234, 181, 173], 'logprob': -7.896309739408025e-07, 'top_logprobs': []}, {'token': '의', 'bytes': [236, 157, 152], 'logprob': -1.9361264946837764e-07, 'top_logprobs': []}, {'token': ' 수도', 'bytes': [32, 236, 136, 152, 235, 143, 132], 'logprob': -9.372294698550832e-06, 'top_logprobs': []}, {'token': '는', 'bytes': [235, 138, 148], 'logprob': -8.387458365177736e-05, 'top_logprobs': []}, {'token': ' 워', 'bytes': [32, 236, 155, 140], 'logprob': -0.0009561245678924024, 'top_logprobs': []}, {'token': '싱', 'bytes': [236, 139, 177], 'logprob': -1.9623810658231378e-05, 'top_logprobs': []}, {'token': '턴', 'bytes': [237, 132, 180], 'logprob': -1.5690089639974758e-05, 'top_logprobs': []}, {'token': ' D', 'bytes': [32, 68], 'logprob': -0.00015502817404922098, 'top_logprobs': []}, {'token': '.C', 'bytes': [46, 67], 'logprob': -1.9361264946837764e-07, 'top_logprobs': []}, {'token': '.', 'bytes': [46], 'logprob': -0.0005765048554167151, 'top_logprobs': []}, {'token': '입니다', 'bytes': [236, 158, 133, 235, 139, 136, 235, 139, 164], 'logprob': -0.03070835955440998, 'top_logprobs': []}, {'token': '.', 'bytes': [46], 'logprob': -3.128163257315464e-07, 'top_logprobs': []}], 'refusal': None}} id='lc_run--01a09ef6-2e5b-7ef3-b0e4-01c29c7347e3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 13, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
response.content
response.response_metadata
response.response_metadata["token_usage"]["total_tokens"]
# Out:
# 28

# %%
print(response.content)
print(response.response_metadata["logprobs"])
# Out:
# 미국의 수도는 워싱턴 D.C.입니다.
# {'content': [{'token': '미', 'bytes': [235, 175, 184], 'logprob': -0.00013095269969198853, 'top_logprobs': []}, {'token': '국', 'bytes': [234, 181, 173], 'logprob': -7.896309739408025e-07, 'top_logprobs': []}, {'token': '의', 'bytes': [236, 157, 152], 'logprob': -1.9361264946837764e-07, 'top_logprobs': []}, {'token': ' 수도', 'bytes': [32, 236, 136, 152, 235, 143, 132], 'logprob': -9.372294698550832e-06, 'top_logprobs': []}, {'token': '는', 'bytes': [235, 138, 148], 'logprob': -8.387458365177736e-05, 'top_logprobs': []}, {'token': ' 워', 'bytes': [32, 236, 155, 140], 'logprob': -0.0009561245678924024, 'top_logprobs': []}, {'token': '싱', 'bytes': [236, 139, 177], 'logprob': -1.9623810658231378e-05, 'top_logprobs': []}, {'token': '턴', 'bytes': [237, 132, 180], 'logprob': -1.5690089639974758e-05, 'top_logprobs': []}, {'token': ' D', 'bytes': [32, 68], 'logprob': -0.00015502817404922098, 'top_logprobs': []}, {'token': '.C', 'bytes': [46, 67], 'logprob': -1.9361264946837764e-07, 'top_logprobs': []}, {'token': '.', 'bytes': [46], 'logprob': -0.0005765048554167151, 'top_logprobs': []}, {'token': '입니다', 'bytes': [236, 158, 133, 235, 139, 136, 235, 139, 164], 'logprob': -0.03070835955440998, 'top_logprobs': []}, {'token': '.', 'bytes': [46], 'logprob': -3.128163257315464e-07, 'top_logprobs': []}], 'refusal': None}

# %%
# Stream 출력 + 최종 답변 저장
answer = llm.stream(
    "대한민국의 아름다운 관광지 10곳과 주소를 알려주세요!"
)

final_answer = ""

for token in answer:
    print(token.content, end="", flush=True)
    final_answer += token.content
# Out:
# 좋아요! 아래는 한국에서 특히 아름답다고 알려진 관광지 10곳과 대략적인 위치 정보입니다. 정확한 상세 주소는 방문 시점에 공식 사이트나 지도에서 확인하시는 것을 권장드립니다. 원하시면 각 장소의 정확한 주소와 지도 링크까지 바로 찾아 드리겠습니다.
#
# 1) 경복궁 (서울) – 서울특별시 종로구
# 2) 해운대해수욕장 (부산) – 부산광역시 해운대구
# 3) 광안리해수욕장 (부산) – 부산광역시 수영구
# 4) 경포대해변/경포해변 (강릉) – 강원도 강릉시
# 5) 설악산국립공원 (강원) – 강원도 속초시/인제군 인근 지역
# 6) 남이섬 (가평/청평 인근) – 경기도 가평군
# 7) 전주 한옥마을 (전주) – 전라북도 전주시 완산구
# 8) 경주 불국사 (경주) – 경상북도 경주시
# 9) 하회마을 (안동) – 경상북도 안동시
# 10) 제주 성산일출봉 (제주) – 제주특별자치도 서귀포시 성산읍
#
# 정확한 주소가 필요하시면 제가 각 장소의 최신 공식 주소와 지도 링크를 확인해 드릴게요. 어떤 형식의 주소를 원하시나요? (예: 한 줄에 장소명 + 전체 주소, 혹은 지도 링크 포함 등)

# %%
print(final_answer)
# Out:
# 좋아요! 아래는 한국에서 특히 아름답다고 알려진 관광지 10곳과 대략적인 위치 정보입니다. 정확한 상세 주소는 방문 시점에 공식 사이트나 지도에서 확인하시는 것을 권장드립니다. 원하시면 각 장소의 정확한 주소와 지도 링크까지 바로 찾아 드리겠습니다.
#
# 1) 경복궁 (서울) – 서울특별시 종로구
# 2) 해운대해수욕장 (부산) – 부산광역시 해운대구
# 3) 광안리해수욕장 (부산) – 부산광역시 수영구
# 4) 경포대해변/경포해변 (강릉) – 강원도 강릉시
# 5) 설악산국립공원 (강원) – 강원도 속초시/인제군 인근 지역
# 6) 남이섬 (가평/청평 인근) – 경기도 가평군
# 7) 전주 한옥마을 (전주) – 전라북도 전주시 완산구
# 8) 경주 불국사 (경주) – 경상북도 경주시
# 9) 하회마을 (안동) – 경상북도 안동시
# 10) 제주 성산일출봉 (제주) – 제주특별자치도 서귀포시 성산읍
#
# 정확한 주소가 필요하시면 제가 각 장소의 최신 공식 주소와 지도 링크를 확인해 드릴게요. 어떤 형식의 주소를 원하시나요? (예: 한 줄에 장소명 + 전체 주소, 혹은 지도 링크 포함 등)
