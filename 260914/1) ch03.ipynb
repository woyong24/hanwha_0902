# %%
# 가상환경 위치 확인
# !pip --version

# %%
# !pip install dotenv

# %%
from dotenv import load_dotenv

load_dotenv()

# %%
import os

print(f"키 값은: {os.environ['OPENAI_API_KEY'][:8]}")
# Out:
# 키 값은: sk-proj-
